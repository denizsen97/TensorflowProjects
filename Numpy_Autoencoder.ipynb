# %% [markdown]
# In this part, you are going to implement a two-layer fully connected autoencoder on MNIST handwritten digits dataset without any deep learning libraries, using numpy only.
#
# Important notes:
#
# - Variables are named in this assignmend regarding following conventions:
#
#      - Constants are named with uppercase words separated with underscores. eg. `INPUT_SIZE`, `LEARNING_RATE`.
#
#      - Derivative of variables are named as variable name with `D_` prefix. For example, `D_x` indicates $\frac{\partial x}{\partial loss}$
#
#      - Output of a layer n before activation function is denoted as `hn`. For example, output of first layer before activation is denoted as `h1`.
#
#      - Similarly, output of a layer n after activation function is denoted as `on`. For example, output of first layer after activation is denoted as `o1`.
#
#
# - The parts you need to fill in are marked with `##FILL HERE` comments. You should only change the lines marked with this comment. Also, you should not change the variable names in the marked lines.
#
# - Try to use 'vectorized' code, that is, avoid for loops as much as possible and use vector and matrix operations instead. Not only performance of your code will be much higher, but also conforming to vectorized mindset makes everything easier for you when dealing with data science/machine learning problems.
#
# - Recommended watch before starting the assignment, https://www.youtube.com/watch?v=lFOOjeH2wsY

# %% [markdown]
# # 1) Boilerplate, imports, data loading

# %%
# %tensorflow_version 1.x
from mmi727_utils import load_dataset, test_relu, test_sigmoid, test_mean_squared_error, test_sigmoid_backward, test_weights
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# load_dataset function; 
# - takes training set of MNIST dataset from tf datasets,
# - flattens 28x28 images to 784 dimensional vectors
# - scales training instances between 0 and 1
# note: Since you are implementing an autoencoder, labes

X = load_dataset()
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # 2) Initialize Weights

# %% [markdown]
# Randomly initialize layer 1 and layer 2 weights as 2D numpy arrays with zero mean and 0.01 standard deviation. For simplicity, biases are omitted.

# %%
INPUT_SIZE  = X.shape[1]
HIDDEN_SIZE = 64

w1 = np.random.normal(0, 0.01, (INPUT_SIZE, HIDDEN_SIZE)) ## FILL HERE ##
w2 = np.random.normal(0, 0.01, (HIDDEN_SIZE, INPUT_SIZE)) ## FILL HERE ##

# %% [markdown]
# # 3) Define activation functions
#
# In this part, we will define the necessary function in numpy. Note that all functions need to operate on batches, not single instances. As a convention, first dimension of all tensors will be the batch dimension.

# %% [markdown]
# Define relu and sigmoid activation functions in forward mode.

# %%
def relu(x):
    ################
    ### FILL HERE ##
    ################
    return np.maximum(x, 0)

# %%
def sigmoid(x):
    ################
    ### FILL HERE ##
    ################
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# # 4.a) Define activation functions in 'backward mode'
# Suppose you know the derivative of a function's output with respect to the loss, which is $\frac{\partial loss}{\partial f(x)}$. Backward mode of a function takes $\frac{\partial loss}{\partial f(x)}$ (```D_output``` argument) and gives derivatives of its input with respect to the loss $\frac{\partial loss}{\partial x}$.

# %% [markdown]
# Backward mode of relu is defined below. Using this as an example, sigmoid activation function in backward mode. You are going to use these functions to implement backpropagation.

# %%
#Note: If you are confused about D_output means, read the notes at the top of the page.
def relu_backward(D_output, output):
    '''
    relu_backward: Backward mode of relu activation function
    
    Arguments;
    D_output: Derivative of output of relu with respect to loss.
    output  : Output of relu activation function
    
    Returns;
    Derivative of input of relu function with respect to loss.
    '''
    ################
    ### FILL HERE ##
    ################

    return D_output * np.where(output <= 0, 0, 1).astype('float64')

# %%
def sigmoid_backward(D_output, output):    
    '''
    sigmoid_backward: Backward mode of sigmoid activation function
    
    Arguments;
    D_output: Derivative of output of sigmoid with respect to loss.
    output  : Output of sigmoid activation function
    
    Returns;
    Derivative of input of sigmoid function with respect to loss.
    '''
    ################
    ### FILL HERE ##
    ################
    return D_output * output * (1 - output)

# %% [markdown]
# # 4.b) Define loss function

# %% [markdown]
# Define the function computing mean squared error metric, given outputs and targets.

# %%
def mean_squared_error(outputs, targets):
    squared_errors = (np.square(outputs - targets))## FILL HERE ##
    return np.mean(squared_errors)

# %% [markdown]
# # 5) Sanity Check
# Since Part 6 will be a little more difficult than the other parts, make sure everything is correct so far using test scripts before proceeding Part 6,(just run the cell below). If anything is incorrect with your implementations, do not start implementing part 6 before fixing the mistakes and making sure everything works as intended.
#
# Note: Don't forget to run cells after making changes in them or you may re-test your old implementations unintentionally.

# %%
test_weights(w1, w2, INPUT_SIZE, HIDDEN_SIZE)
test_relu(relu)
test_sigmoid(sigmoid)
test_sigmoid_backward(sigmoid_backward)
test_mean_squared_error(mean_squared_error)
# Out:
# Success: Weights are initialized properly.
# Success: 'relu' is implemented properly.
# Success: 'sigmoid' is implemented properly.
# Success: 'sigmoid_backward' is implemented properly.
# Success: 'mean_squared_error' is implemented properly.

# %% [markdown]
# # 6) Training

# %% [markdown]
# Set hyperparameters

# %%
BATCH_SIZE = 1024
NUM_EPOCHS = 10
LEARNING_RATE = 0.0001

# %% [markdown]
# Calculate how many iterations will be done per epoch.
#
# Hint: You may want to use `//` operator, which does integer division in Python 3.

# %%
NUM_TRAINING_INSTANCES = X.shape[0]

# %%
ITERATIONS_PER_EPOCH = NUM_TRAINING_INSTANCES // BATCH_SIZE ## FILL HERE ##

# %%
import os
if not os.path.exists('output'):
    os.makedirs('output')

# %% [markdown]
# Training loop mainly consists of 4 steps
#
# 1) Sample batch from dataset
#
# 2) Forward propagation
#
# 3) Backpropagation
#
# 4) Parameter updates
#
# 1st and 4th steps are implemented. You are expected to implement forward propagation and backpropagation using the functions you defined above.
#
# - You can use ```@``` operator or ```np.dot``` function for matrix multiplication.
# - Note that you have implemented every backward operation needed, except matrix multiplication. Find out what is the backward mode of matrix multiplication operation. Or derive it, if you feel adventurous.

# %%
# If you are confused what h1, o1, D_w1, etc. means, 
#   refer to the notes at the top of the notebook.
# Otherwise, feel free to delete this comment.
losses = []

for epoch in range(NUM_EPOCHS): 
    for n in range(ITERATIONS_PER_EPOCH):
        
        ## Sample batch from dataset
        batch_indices = range(n*BATCH_SIZE, n*BATCH_SIZE + BATCH_SIZE)   
        X_batch = X[batch_indices]


        ## Forward propagation
        h1 = np.dot(X_batch, w1)## FILL HERE ##

        
        o1 = relu(h1)## FILL HERE ##
        h2 = np.dot(o1, w2)## FILL HERE ##

        o2 = sigmoid(h2)## FILL HERE ##

      
        loss = mean_squared_error(o2, X_batch)
        losses.append(loss)
        print('Epoch %d, Iteration %d -- Loss: %.6f' % (epoch + 1, epoch * ITERATIONS_PER_EPOCH + n, loss))
            
        ## Backpropagation
        D_o2 = 2 * (o2 - X_batch) # Can you explain why? # derivative of sqared error
        D_h2 = sigmoid_backward(D_o2, o2)


        D_o1 = np.dot(D_h2, w2.T) ## FILL HERE ##
        D_w2 = np.dot(o1.T, D_h2) ## FILL HERE ##
        D_h1 = relu_backward(D_o1, o1) ## FILL HERE ##
        
        D_w1 = np.dot(X_batch.T, D_h1) ## FILL HERE ##
        
        ## Parameter updates
        w1 -= D_w1 * LEARNING_RATE
        w2 -= D_w2 * LEARNING_RATE


       
        if n % 10 == 0:
            plt.figure()
            plt.title('Original %d dimensional image' % INPUT_SIZE)
            plt.imshow(X_batch[0].reshape(28, 28)); plt.show()
            
            
            plt.figure()
            plt.title('Reconstruction from %d dimensional representation' % HIDDEN_SIZE)
            plt.imshow(o2[0].reshape(28, 28)); plt.show()
# Out:
# Epoch 1, Iteration 0 -- Loss: 0.231331
# Epoch 1, Iteration 1 -- Loss: 0.230440
# Epoch 1, Iteration 2 -- Loss: 0.209267
# Epoch 1, Iteration 3 -- Loss: 0.076537
# Epoch 1, Iteration 4 -- Loss: 0.077755
# Epoch 1, Iteration 5 -- Loss: 0.092599
# Epoch 1, Iteration 6 -- Loss: 0.091571
# Epoch 1, Iteration 7 -- Loss: 0.086736
# Epoch 1, Iteration 8 -- Loss: 0.087138
# Epoch 1, Iteration 9 -- Loss: 0.082729
# Epoch 1, Iteration 10 -- Loss: 0.082402
# Epoch 1, Iteration 11 -- Loss: 0.075818
# Epoch 1, Iteration 12 -- Loss: 0.079722
# Epoch 1, Iteration 13 -- Loss: 0.079550
# Epoch 1, Iteration 14 -- Loss: 0.072231
# Epoch 1, Iteration 15 -- Loss: 0.071040
# Epoch 1, Iteration 16 -- Loss: 0.070839
# Epoch 1, Iteration 17 -- Loss: 0.067975
# Epoch 1, Iteration 18 -- Loss: 0.070645
# Epoch 1, Iteration 19 -- Loss: 0.074441
# Epoch 1, Iteration 20 -- Loss: 0.072571
# Epoch 1, Iteration 21 -- Loss: 0.071198
# Epoch 1, Iteration 22 -- Loss: 0.070087
# Epoch 1, Iteration 23 -- Loss: 0.066953
# Epoch 1, Iteration 24 -- Loss: 0.065291
# Epoch 1, Iteration 25 -- Loss: 0.064136
# Epoch 1, Iteration 26 -- Loss: 0.064358
# Epoch 1, Iteration 27 -- Loss: 0.062811
# Epoch 1, Iteration 28 -- Loss: 0.060981
# Epoch 1, Iteration 29 -- Loss: 0.058718
# Epoch 1, Iteration 30 -- Loss: 0.056657
# Epoch 1, Iteration 31 -- Loss: 0.059755
# Epoch 1, Iteration 32 -- Loss: 0.060460
# Epoch 1, Iteration 33 -- Loss: 0.062082
# Epoch 1, Iteration 34 -- Loss: 0.060748
# Epoch 1, Iteration 35 -- Loss: 0.060812
# Epoch 1, Iteration 36 -- Loss: 0.057601
# Epoch 1, Iteration 37 -- Loss: 0.056092
# Epoch 1, Iteration 38 -- Loss: 0.056340
# Epoch 1, Iteration 39 -- Loss: 0.054701
# Epoch 1, Iteration 40 -- Loss: 0.054546
# Epoch 1, Iteration 41 -- Loss: 0.055207
# Epoch 1, Iteration 42 -- Loss: 0.054284
# Epoch 1, Iteration 43 -- Loss: 0.056512
# Epoch 1, Iteration 44 -- Loss: 0.052644
# Epoch 1, Iteration 45 -- Loss: 0.049613
# Epoch 1, Iteration 46 -- Loss: 0.049697
# Epoch 1, Iteration 47 -- Loss: 0.049592
# Epoch 1, Iteration 48 -- Loss: 0.050397
# Epoch 1, Iteration 49 -- Loss: 0.048751
# Epoch 1, Iteration 50 -- Loss: 0.049936
# Epoch 1, Iteration 51 -- Loss: 0.045937
# Epoch 1, Iteration 52 -- Loss: 0.046871
# Epoch 1, Iteration 53 -- Loss: 0.046025
# Epoch 1, Iteration 54 -- Loss: 0.045020
# Epoch 1, Iteration 55 -- Loss: 0.044794
# Epoch 1, Iteration 56 -- Loss: 0.043730
# Epoch 1, Iteration 57 -- Loss: 0.042147
# Epoch 2, Iteration 58 -- Loss: 0.042090
# Epoch 2, Iteration 59 -- Loss: 0.044417
# Epoch 2, Iteration 60 -- Loss: 0.044013
# Epoch 2, Iteration 61 -- Loss: 0.041607
# Epoch 2, Iteration 62 -- Loss: 0.043703
# Epoch 2, Iteration 63 -- Loss: 0.043050
# Epoch 2, Iteration 64 -- Loss: 0.043602
# Epoch 2, Iteration 65 -- Loss: 0.043849
# Epoch 2, Iteration 66 -- Loss: 0.043596
# Epoch 2, Iteration 67 -- Loss: 0.043790
# Epoch 2, Iteration 68 -- Loss: 0.043534
# Epoch 2, Iteration 69 -- Loss: 0.041299
# Epoch 2, Iteration 70 -- Loss: 0.045409
# Epoch 2, Iteration 71 -- Loss: 0.043532
# Epoch 2, Iteration 72 -- Loss: 0.041493
# Epoch 2, Iteration 73 -- Loss: 0.039528
# Epoch 2, Iteration 74 -- Loss: 0.039690
# Epoch 2, Iteration 75 -- Loss: 0.038378
# Epoch 2, Iteration 76 -- Loss: 0.039874
# Epoch 2, Iteration 77 -- Loss: 0.040977
# Epoch 2, Iteration 78 -- Loss: 0.039843
# Epoch 2, Iteration 79 -- Loss: 0.040621
# Epoch 2, Iteration 80 -- Loss: 0.040474
# Epoch 2, Iteration 81 -- Loss: 0.040249
# Epoch 2, Iteration 82 -- Loss: 0.038527
# Epoch 2, Iteration 83 -- Loss: 0.037689
# Epoch 2, Iteration 84 -- Loss: 0.038543
# Epoch 2, Iteration 85 -- Loss: 0.037337
# Epoch 2, Iteration 86 -- Loss: 0.037976
# Epoch 2, Iteration 87 -- Loss: 0.036932
# Epoch 2, Iteration 88 -- Loss: 0.036110
# Epoch 2, Iteration 89 -- Loss: 0.036667
# Epoch 2, Iteration 90 -- Loss: 0.035434
# Epoch 2, Iteration 91 -- Loss: 0.034677
# Epoch 2, Iteration 92 -- Loss: 0.035694
# Epoch 2, Iteration 93 -- Loss: 0.040182
# Epoch 2, Iteration 94 -- Loss: 0.038671
# Epoch 2, Iteration 95 -- Loss: 0.036606
# Epoch 2, Iteration 96 -- Loss: 0.036333
# Epoch 2, Iteration 97 -- Loss: 0.034925
# Epoch 2, Iteration 98 -- Loss: 0.036017
# Epoch 2, Iteration 99 -- Loss: 0.034893
# Epoch 2, Iteration 100 -- Loss: 0.033326
# Epoch 2, Iteration 101 -- Loss: 0.034709
# Epoch 2, Iteration 102 -- Loss: 0.035553
# Epoch 2, Iteration 103 -- Loss: 0.035028
# Epoch 2, Iteration 104 -- Loss: 0.035881
# Epoch 2, Iteration 105 -- Loss: 0.036642
# Epoch 2, Iteration 106 -- Loss: 0.036713
# Epoch 2, Iteration 107 -- Loss: 0.033923
# Epoch 2, Iteration 108 -- Loss: 0.034408
# Epoch 2, Iteration 109 -- Loss: 0.031625
# Epoch 2, Iteration 110 -- Loss: 0.033005
# Epoch 2, Iteration 111 -- Loss: 0.032416
# Epoch 2, Iteration 112 -- Loss: 0.032218
# Epoch 2, Iteration 113 -- Loss: 0.031959
# Epoch 2, Iteration 114 -- Loss: 0.031294
# Epoch 2, Iteration 115 -- Loss: 0.030390
# Epoch 3, Iteration 116 -- Loss: 0.029727
# Epoch 3, Iteration 117 -- Loss: 0.032617
# Epoch 3, Iteration 118 -- Loss: 0.032129
# Epoch 3, Iteration 119 -- Loss: 0.030616
# Epoch 3, Iteration 120 -- Loss: 0.031529
# Epoch 3, Iteration 121 -- Loss: 0.031692
# Epoch 3, Iteration 122 -- Loss: 0.032765
# Epoch 3, Iteration 123 -- Loss: 0.032346
# Epoch 3, Iteration 124 -- Loss: 0.031403
# Epoch 3, Iteration 125 -- Loss: 0.031731
# Epoch 3, Iteration 126 -- Loss: 0.030586
# Epoch 3, Iteration 127 -- Loss: 0.029210
# Epoch 3, Iteration 128 -- Loss: 0.032887
# Epoch 3, Iteration 129 -- Loss: 0.032451
# Epoch 3, Iteration 130 -- Loss: 0.032099
# Epoch 3, Iteration 131 -- Loss: 0.030198
# Epoch 3, Iteration 132 -- Loss: 0.030280
# Epoch 3, Iteration 133 -- Loss: 0.029235
# Epoch 3, Iteration 134 -- Loss: 0.030424
# Epoch 3, Iteration 135 -- Loss: 0.030806
# Epoch 3, Iteration 136 -- Loss: 0.030426
# Epoch 3, Iteration 137 -- Loss: 0.031145
# Epoch 3, Iteration 138 -- Loss: 0.030543
# Epoch 3, Iteration 139 -- Loss: 0.031163
# Epoch 3, Iteration 140 -- Loss: 0.030535
# Epoch 3, Iteration 141 -- Loss: 0.030406
# Epoch 3, Iteration 142 -- Loss: 0.030853
# Epoch 3, Iteration 143 -- Loss: 0.029790
# Epoch 3, Iteration 144 -- Loss: 0.030734
# Epoch 3, Iteration 145 -- Loss: 0.029813
# Epoch 3, Iteration 146 -- Loss: 0.028994
# Epoch 3, Iteration 147 -- Loss: 0.029405
# Epoch 3, Iteration 148 -- Loss: 0.028237
# Epoch 3, Iteration 149 -- Loss: 0.027613
# Epoch 3, Iteration 150 -- Loss: 0.028204
# Epoch 3, Iteration 151 -- Loss: 0.032250
# Epoch 3, Iteration 152 -- Loss: 0.030089
# Epoch 3, Iteration 153 -- Loss: 0.028119
# Epoch 3, Iteration 154 -- Loss: 0.028223
# Epoch 3, Iteration 155 -- Loss: 0.027700
# Epoch 3, Iteration 156 -- Loss: 0.029248
# Epoch 3, Iteration 157 -- Loss: 0.028473
# Epoch 3, Iteration 158 -- Loss: 0.027429
# Epoch 3, Iteration 159 -- Loss: 0.028243
# Epoch 3, Iteration 160 -- Loss: 0.028540
# Epoch 3, Iteration 161 -- Loss: 0.027677
# Epoch 3, Iteration 162 -- Loss: 0.027970
# Epoch 3, Iteration 163 -- Loss: 0.028179
# Epoch 3, Iteration 164 -- Loss: 0.028308
# Epoch 3, Iteration 165 -- Loss: 0.026979
# Epoch 3, Iteration 166 -- Loss: 0.027589
# Epoch 3, Iteration 167 -- Loss: 0.025638
# Epoch 3, Iteration 168 -- Loss: 0.027049
# Epoch 3, Iteration 169 -- Loss: 0.026649
# Epoch 3, Iteration 170 -- Loss: 0.026695
# Epoch 3, Iteration 171 -- Loss: 0.026238
# Epoch 3, Iteration 172 -- Loss: 0.025843
# Epoch 3, Iteration 173 -- Loss: 0.024992
# Epoch 4, Iteration 174 -- Loss: 0.024360
# Epoch 4, Iteration 175 -- Loss: 0.027358
# Epoch 4, Iteration 176 -- Loss: 0.026683
# Epoch 4, Iteration 177 -- Loss: 0.025583
# Epoch 4, Iteration 178 -- Loss: 0.026287
# Epoch 4, Iteration 179 -- Loss: 0.026568
# Epoch 4, Iteration 180 -- Loss: 0.028437
# Epoch 4, Iteration 181 -- Loss: 0.028547
# Epoch 4, Iteration 182 -- Loss: 0.027204
# Epoch 4, Iteration 183 -- Loss: 0.027497
# Epoch 4, Iteration 184 -- Loss: 0.025976
# Epoch 4, Iteration 185 -- Loss: 0.025112
# Epoch 4, Iteration 186 -- Loss: 0.028050
# Epoch 4, Iteration 187 -- Loss: 0.027692
# Epoch 4, Iteration 188 -- Loss: 0.027102
# Epoch 4, Iteration 189 -- Loss: 0.025393
# Epoch 4, Iteration 190 -- Loss: 0.025647
# Epoch 4, Iteration 191 -- Loss: 0.024728
# Epoch 4, Iteration 192 -- Loss: 0.025462
# Epoch 4, Iteration 193 -- Loss: 0.025815
# Epoch 4, Iteration 194 -- Loss: 0.025950
# Epoch 4, Iteration 195 -- Loss: 0.027218
# Epoch 4, Iteration 196 -- Loss: 0.025896
# Epoch 4, Iteration 197 -- Loss: 0.026166
# Epoch 4, Iteration 198 -- Loss: 0.025261
# Epoch 4, Iteration 199 -- Loss: 0.024736
# Epoch 4, Iteration 200 -- Loss: 0.025211
# Epoch 4, Iteration 201 -- Loss: 0.024520
# Epoch 4, Iteration 202 -- Loss: 0.025411
# Epoch 4, Iteration 203 -- Loss: 0.024704
# Epoch 4, Iteration 204 -- Loss: 0.024563
# Epoch 4, Iteration 205 -- Loss: 0.024958
# Epoch 4, Iteration 206 -- Loss: 0.024423
# Epoch 4, Iteration 207 -- Loss: 0.024222
# Epoch 4, Iteration 208 -- Loss: 0.025028
# Epoch 4, Iteration 209 -- Loss: 0.029159
# Epoch 4, Iteration 210 -- Loss: 0.026898
# Epoch 4, Iteration 211 -- Loss: 0.024285
# Epoch 4, Iteration 212 -- Loss: 0.024080
# Epoch 4, Iteration 213 -- Loss: 0.022959
# Epoch 4, Iteration 214 -- Loss: 0.024428
# Epoch 4, Iteration 215 -- Loss: 0.023724
# Epoch 4, Iteration 216 -- Loss: 0.022938
# Epoch 4, Iteration 217 -- Loss: 0.023651
# Epoch 4, Iteration 218 -- Loss: 0.024317
# Epoch 4, Iteration 219 -- Loss: 0.023950
# Epoch 4, Iteration 220 -- Loss: 0.023994
# Epoch 4, Iteration 221 -- Loss: 0.024146
# Epoch 4, Iteration 222 -- Loss: 0.024812
# Epoch 4, Iteration 223 -- Loss: 0.023828
# Epoch 4, Iteration 224 -- Loss: 0.024499
# Epoch 4, Iteration 225 -- Loss: 0.022753
# Epoch 4, Iteration 226 -- Loss: 0.024055
# Epoch 4, Iteration 227 -- Loss: 0.023696
# Epoch 4, Iteration 228 -- Loss: 0.023334
# Epoch 4, Iteration 229 -- Loss: 0.022367
# Epoch 4, Iteration 230 -- Loss: 0.022099
# Epoch 4, Iteration 231 -- Loss: 0.021372
# Epoch 5, Iteration 232 -- Loss: 0.020731
# Epoch 5, Iteration 233 -- Loss: 0.023424
# Epoch 5, Iteration 234 -- Loss: 0.022425
# Epoch 5, Iteration 235 -- Loss: 0.021548
# Epoch 5, Iteration 236 -- Loss: 0.022227
# Epoch 5, Iteration 237 -- Loss: 0.022538
# Epoch 5, Iteration 238 -- Loss: 0.023749
# Epoch 5, Iteration 239 -- Loss: 0.024213
# Epoch 5, Iteration 240 -- Loss: 0.023778
# Epoch 5, Iteration 241 -- Loss: 0.025086
# Epoch 5, Iteration 242 -- Loss: 0.023891
# Epoch 5, Iteration 243 -- Loss: 0.024095
# Epoch 5, Iteration 244 -- Loss: 0.025771
# Epoch 5, Iteration 245 -- Loss: 0.025750
# Epoch 5, Iteration 246 -- Loss: 0.024010
# Epoch 5, Iteration 247 -- Loss: 0.021803
# Epoch 5, Iteration 248 -- Loss: 0.021656
# Epoch 5, Iteration 249 -- Loss: 0.020888
# Epoch 5, Iteration 250 -- Loss: 0.021588
# Epoch 5, Iteration 251 -- Loss: 0.021447
# Epoch 5, Iteration 252 -- Loss: 0.021222
# Epoch 5, Iteration 253 -- Loss: 0.022889
# Epoch 5, Iteration 254 -- Loss: 0.021781
# Epoch 5, Iteration 255 -- Loss: 0.023263
# Epoch 5, Iteration 256 -- Loss: 0.023828
# Epoch 5, Iteration 257 -- Loss: 0.023504
# Epoch 5, Iteration 258 -- Loss: 0.023399
# Epoch 5, Iteration 259 -- Loss: 0.022043
# Epoch 5, Iteration 260 -- Loss: 0.022561
# Epoch 5, Iteration 261 -- Loss: 0.021976
# Epoch 5, Iteration 262 -- Loss: 0.021636
# Epoch 5, Iteration 263 -- Loss: 0.021699
# Epoch 5, Iteration 264 -- Loss: 0.020997
# Epoch 5, Iteration 265 -- Loss: 0.020829
# Epoch 5, Iteration 266 -- Loss: 0.021386
# Epoch 5, Iteration 267 -- Loss: 0.025144
# Epoch 5, Iteration 268 -- Loss: 0.023175
# Epoch 5, Iteration 269 -- Loss: 0.021125
# Epoch 5, Iteration 270 -- Loss: 0.021227
# Epoch 5, Iteration 271 -- Loss: 0.020193
# Epoch 5, Iteration 272 -- Loss: 0.021657
# Epoch 5, Iteration 273 -- Loss: 0.021052
# Epoch 5, Iteration 274 -- Loss: 0.020814
# Epoch 5, Iteration 275 -- Loss: 0.021176
# Epoch 5, Iteration 276 -- Loss: 0.021932
# Epoch 5, Iteration 277 -- Loss: 0.021600
# Epoch 5, Iteration 278 -- Loss: 0.021518
# Epoch 5, Iteration 279 -- Loss: 0.021531
# Epoch 5, Iteration 280 -- Loss: 0.022200
# Epoch 5, Iteration 281 -- Loss: 0.021220
# Epoch 5, Iteration 282 -- Loss: 0.021599
# Epoch 5, Iteration 283 -- Loss: 0.019928
# Epoch 5, Iteration 284 -- Loss: 0.021240
# Epoch 5, Iteration 285 -- Loss: 0.021086
# Epoch 5, Iteration 286 -- Loss: 0.020974
# Epoch 5, Iteration 287 -- Loss: 0.019774
# Epoch 5, Iteration 288 -- Loss: 0.019617
# Epoch 5, Iteration 289 -- Loss: 0.019135
# Epoch 6, Iteration 290 -- Loss: 0.018545
# Epoch 6, Iteration 291 -- Loss: 0.021314
# Epoch 6, Iteration 292 -- Loss: 0.020688
# Epoch 6, Iteration 293 -- Loss: 0.019566
# Epoch 6, Iteration 294 -- Loss: 0.019711
# Epoch 6, Iteration 295 -- Loss: 0.020196
# Epoch 6, Iteration 296 -- Loss: 0.021394
# Epoch 6, Iteration 297 -- Loss: 0.021540
# Epoch 6, Iteration 298 -- Loss: 0.020353
# Epoch 6, Iteration 299 -- Loss: 0.020996
# Epoch 6, Iteration 300 -- Loss: 0.020058
# Epoch 6, Iteration 301 -- Loss: 0.020698
# Epoch 6, Iteration 302 -- Loss: 0.022627
# Epoch 6, Iteration 303 -- Loss: 0.023220
# Epoch 6, Iteration 304 -- Loss: 0.021568
# Epoch 6, Iteration 305 -- Loss: 0.019586
# Epoch 6, Iteration 306 -- Loss: 0.019432
# Epoch 6, Iteration 307 -- Loss: 0.018797
# Epoch 6, Iteration 308 -- Loss: 0.019383
# Epoch 6, Iteration 309 -- Loss: 0.019233
# Epoch 6, Iteration 310 -- Loss: 0.019081
# Epoch 6, Iteration 311 -- Loss: 0.020755
# Epoch 6, Iteration 312 -- Loss: 0.019612
# Epoch 6, Iteration 313 -- Loss: 0.021072
# Epoch 6, Iteration 314 -- Loss: 0.021311
# Epoch 6, Iteration 315 -- Loss: 0.021711
# Epoch 6, Iteration 316 -- Loss: 0.021218
# Epoch 6, Iteration 317 -- Loss: 0.020020
# Epoch 6, Iteration 318 -- Loss: 0.020262
# Epoch 6, Iteration 319 -- Loss: 0.019969
# Epoch 6, Iteration 320 -- Loss: 0.019617
# Epoch 6, Iteration 321 -- Loss: 0.019531
# Epoch 6, Iteration 322 -- Loss: 0.019133
# Epoch 6, Iteration 323 -- Loss: 0.019145
# Epoch 6, Iteration 324 -- Loss: 0.019878
# Epoch 6, Iteration 325 -- Loss: 0.023749
# Epoch 6, Iteration 326 -- Loss: 0.022157
# Epoch 6, Iteration 327 -- Loss: 0.019718
# Epoch 6, Iteration 328 -- Loss: 0.019476
# Epoch 6, Iteration 329 -- Loss: 0.018330
# Epoch 6, Iteration 330 -- Loss: 0.019567
# Epoch 6, Iteration 331 -- Loss: 0.018774
# Epoch 6, Iteration 332 -- Loss: 0.018263
# Epoch 6, Iteration 333 -- Loss: 0.018738
# Epoch 6, Iteration 334 -- Loss: 0.019506
# Epoch 6, Iteration 335 -- Loss: 0.019229
# Epoch 6, Iteration 336 -- Loss: 0.019220
# Epoch 6, Iteration 337 -- Loss: 0.019509
# Epoch 6, Iteration 338 -- Loss: 0.020292
# Epoch 6, Iteration 339 -- Loss: 0.019560
# Epoch 6, Iteration 340 -- Loss: 0.020125
# Epoch 6, Iteration 341 -- Loss: 0.018647
# Epoch 6, Iteration 342 -- Loss: 0.020214
# Epoch 6, Iteration 343 -- Loss: 0.019831
# Epoch 6, Iteration 344 -- Loss: 0.019751
# Epoch 6, Iteration 345 -- Loss: 0.018213
# Epoch 6, Iteration 346 -- Loss: 0.017988
# Epoch 6, Iteration 347 -- Loss: 0.017431
# Epoch 7, Iteration 348 -- Loss: 0.016818
# Epoch 7, Iteration 349 -- Loss: 0.019095
# Epoch 7, Iteration 350 -- Loss: 0.018440
# Epoch 7, Iteration 351 -- Loss: 0.017426
# Epoch 7, Iteration 352 -- Loss: 0.017625
# Epoch 7, Iteration 353 -- Loss: 0.018258
# Epoch 7, Iteration 354 -- Loss: 0.019718
# Epoch 7, Iteration 355 -- Loss: 0.019724
# Epoch 7, Iteration 356 -- Loss: 0.018445
# Epoch 7, Iteration 357 -- Loss: 0.019053
# Epoch 7, Iteration 358 -- Loss: 0.017749
# Epoch 7, Iteration 359 -- Loss: 0.018418
# Epoch 7, Iteration 360 -- Loss: 0.019747
# Epoch 7, Iteration 361 -- Loss: 0.020288
# Epoch 7, Iteration 362 -- Loss: 0.019390
# Epoch 7, Iteration 363 -- Loss: 0.017978
# Epoch 7, Iteration 364 -- Loss: 0.017886
# Epoch 7, Iteration 365 -- Loss: 0.017414
# Epoch 7, Iteration 366 -- Loss: 0.017741
# Epoch 7, Iteration 367 -- Loss: 0.017931
# Epoch 7, Iteration 368 -- Loss: 0.018263
# Epoch 7, Iteration 369 -- Loss: 0.020125
# Epoch 7, Iteration 370 -- Loss: 0.018541
# Epoch 7, Iteration 371 -- Loss: 0.018932
# Epoch 7, Iteration 372 -- Loss: 0.018759
# Epoch 7, Iteration 373 -- Loss: 0.019312
# Epoch 7, Iteration 374 -- Loss: 0.019487
# Epoch 7, Iteration 375 -- Loss: 0.018871
# Epoch 7, Iteration 376 -- Loss: 0.019002
# Epoch 7, Iteration 377 -- Loss: 0.018900
# Epoch 7, Iteration 378 -- Loss: 0.018226
# Epoch 7, Iteration 379 -- Loss: 0.017635
# Epoch 7, Iteration 380 -- Loss: 0.017150
# Epoch 7, Iteration 381 -- Loss: 0.017338
# Epoch 7, Iteration 382 -- Loss: 0.018154
# Epoch 7, Iteration 383 -- Loss: 0.022247
# Epoch 7, Iteration 384 -- Loss: 0.021278
# Epoch 7, Iteration 385 -- Loss: 0.019070
# Epoch 7, Iteration 386 -- Loss: 0.018365
# Epoch 7, Iteration 387 -- Loss: 0.017048
# Epoch 7, Iteration 388 -- Loss: 0.018377
# Epoch 7, Iteration 389 -- Loss: 0.018050
# Epoch 7, Iteration 390 -- Loss: 0.018123
# Epoch 7, Iteration 391 -- Loss: 0.018258
# Epoch 7, Iteration 392 -- Loss: 0.018945
# Epoch 7, Iteration 393 -- Loss: 0.018629
# Epoch 7, Iteration 394 -- Loss: 0.018370
# Epoch 7, Iteration 395 -- Loss: 0.018525
# Epoch 7, Iteration 396 -- Loss: 0.019484
# Epoch 7, Iteration 397 -- Loss: 0.018454
# Epoch 7, Iteration 398 -- Loss: 0.018616
# Epoch 7, Iteration 399 -- Loss: 0.016934
# Epoch 7, Iteration 400 -- Loss: 0.018164
# Epoch 7, Iteration 401 -- Loss: 0.017890
# Epoch 7, Iteration 402 -- Loss: 0.017799
# Epoch 7, Iteration 403 -- Loss: 0.016550
# Epoch 7, Iteration 404 -- Loss: 0.016396
# Epoch 7, Iteration 405 -- Loss: 0.015915
# Epoch 8, Iteration 406 -- Loss: 0.015262
# Epoch 8, Iteration 407 -- Loss: 0.017494
# Epoch 8, Iteration 408 -- Loss: 0.016922
# Epoch 8, Iteration 409 -- Loss: 0.016022
# Epoch 8, Iteration 410 -- Loss: 0.016170
# Epoch 8, Iteration 411 -- Loss: 0.016813
# Epoch 8, Iteration 412 -- Loss: 0.018036
# Epoch 8, Iteration 413 -- Loss: 0.018150
# Epoch 8, Iteration 414 -- Loss: 0.017011
# Epoch 8, Iteration 415 -- Loss: 0.017817
# Epoch 8, Iteration 416 -- Loss: 0.016744
# Epoch 8, Iteration 417 -- Loss: 0.018036
# Epoch 8, Iteration 418 -- Loss: 0.019755
# Epoch 8, Iteration 419 -- Loss: 0.021224
# Epoch 8, Iteration 420 -- Loss: 0.019388
# Epoch 8, Iteration 421 -- Loss: 0.017024
# Epoch 8, Iteration 422 -- Loss: 0.016659
# Epoch 8, Iteration 423 -- Loss: 0.016057
# Epoch 8, Iteration 424 -- Loss: 0.016176
# Epoch 8, Iteration 425 -- Loss: 0.016365
# Epoch 8, Iteration 426 -- Loss: 0.016539
# Epoch 8, Iteration 427 -- Loss: 0.018400
# Epoch 8, Iteration 428 -- Loss: 0.016764
# Epoch 8, Iteration 429 -- Loss: 0.016833
# Epoch 8, Iteration 430 -- Loss: 0.016521
# Epoch 8, Iteration 431 -- Loss: 0.016681
# Epoch 8, Iteration 432 -- Loss: 0.017096
# Epoch 8, Iteration 433 -- Loss: 0.016858
# Epoch 8, Iteration 434 -- Loss: 0.017285
# Epoch 8, Iteration 435 -- Loss: 0.017321
# Epoch 8, Iteration 436 -- Loss: 0.016871
# Epoch 8, Iteration 437 -- Loss: 0.016570
# Epoch 8, Iteration 438 -- Loss: 0.016392
# Epoch 8, Iteration 439 -- Loss: 0.016721
# Epoch 8, Iteration 440 -- Loss: 0.017699
# Epoch 8, Iteration 441 -- Loss: 0.022022
# Epoch 8, Iteration 442 -- Loss: 0.020959
# Epoch 8, Iteration 443 -- Loss: 0.018398
# Epoch 8, Iteration 444 -- Loss: 0.017118
# Epoch 8, Iteration 445 -- Loss: 0.015644
# Epoch 8, Iteration 446 -- Loss: 0.016766
# Epoch 8, Iteration 447 -- Loss: 0.016375
# Epoch 8, Iteration 448 -- Loss: 0.016199
# Epoch 8, Iteration 449 -- Loss: 0.016271
# Epoch 8, Iteration 450 -- Loss: 0.017126
# Epoch 8, Iteration 451 -- Loss: 0.016740
# Epoch 8, Iteration 452 -- Loss: 0.016615
# Epoch 8, Iteration 453 -- Loss: 0.016579
# Epoch 8, Iteration 454 -- Loss: 0.017546
# Epoch 8, Iteration 455 -- Loss: 0.017003
# Epoch 8, Iteration 456 -- Loss: 0.017860
# Epoch 8, Iteration 457 -- Loss: 0.016349
# Epoch 8, Iteration 458 -- Loss: 0.017740
# Epoch 8, Iteration 459 -- Loss: 0.017335
# Epoch 8, Iteration 460 -- Loss: 0.017276
# Epoch 8, Iteration 461 -- Loss: 0.015833
# Epoch 8, Iteration 462 -- Loss: 0.015541
# Epoch 8, Iteration 463 -- Loss: 0.015002
# Epoch 9, Iteration 464 -- Loss: 0.014384
# Epoch 9, Iteration 465 -- Loss: 0.016444
# Epoch 9, Iteration 466 -- Loss: 0.015818
# Epoch 9, Iteration 467 -- Loss: 0.015102
# Epoch 9, Iteration 468 -- Loss: 0.015190
# Epoch 9, Iteration 469 -- Loss: 0.015561
# Epoch 9, Iteration 470 -- Loss: 0.016444
# Epoch 9, Iteration 471 -- Loss: 0.016754
# Epoch 9, Iteration 472 -- Loss: 0.015947
# Epoch 9, Iteration 473 -- Loss: 0.016815
# Epoch 9, Iteration 474 -- Loss: 0.016174
# Epoch 9, Iteration 475 -- Loss: 0.017502
# Epoch 9, Iteration 476 -- Loss: 0.019269
# Epoch 9, Iteration 477 -- Loss: 0.020496
# Epoch 9, Iteration 478 -- Loss: 0.018231
# Epoch 9, Iteration 479 -- Loss: 0.015631
# Epoch 9, Iteration 480 -- Loss: 0.015306
# Epoch 9, Iteration 481 -- Loss: 0.014891
# Epoch 9, Iteration 482 -- Loss: 0.015070
# Epoch 9, Iteration 483 -- Loss: 0.015175
# Epoch 9, Iteration 484 -- Loss: 0.015091
# Epoch 9, Iteration 485 -- Loss: 0.016688
# Epoch 9, Iteration 486 -- Loss: 0.015344
# Epoch 9, Iteration 487 -- Loss: 0.015657
# Epoch 9, Iteration 488 -- Loss: 0.015776
# Epoch 9, Iteration 489 -- Loss: 0.016098
# Epoch 9, Iteration 490 -- Loss: 0.016493
# Epoch 9, Iteration 491 -- Loss: 0.015910
# Epoch 9, Iteration 492 -- Loss: 0.016323
# Epoch 9, Iteration 493 -- Loss: 0.016478
# Epoch 9, Iteration 494 -- Loss: 0.015971
# Epoch 9, Iteration 495 -- Loss: 0.015319
# Epoch 9, Iteration 496 -- Loss: 0.015044
# Epoch 9, Iteration 497 -- Loss: 0.015090
# Epoch 9, Iteration 498 -- Loss: 0.015964
# Epoch 9, Iteration 499 -- Loss: 0.019670
# Epoch 9, Iteration 500 -- Loss: 0.019185
# Epoch 9, Iteration 501 -- Loss: 0.017066
# Epoch 9, Iteration 502 -- Loss: 0.016244
# Epoch 9, Iteration 503 -- Loss: 0.014797
# Epoch 9, Iteration 504 -- Loss: 0.015845
# Epoch 9, Iteration 505 -- Loss: 0.015635
# Epoch 9, Iteration 506 -- Loss: 0.015735
# Epoch 9, Iteration 507 -- Loss: 0.015606
# Epoch 9, Iteration 508 -- Loss: 0.016431
# Epoch 9, Iteration 509 -- Loss: 0.016071
# Epoch 9, Iteration 510 -- Loss: 0.015999
# Epoch 9, Iteration 511 -- Loss: 0.016011
# Epoch 9, Iteration 512 -- Loss: 0.017287
# Epoch 9, Iteration 513 -- Loss: 0.016630
# Epoch 9, Iteration 514 -- Loss: 0.016867
# Epoch 9, Iteration 515 -- Loss: 0.015177
# Epoch 9, Iteration 516 -- Loss: 0.016256
# Epoch 9, Iteration 517 -- Loss: 0.016075
# Epoch 9, Iteration 518 -- Loss: 0.016002
# Epoch 9, Iteration 519 -- Loss: 0.014849
# Epoch 9, Iteration 520 -- Loss: 0.014615
# Epoch 9, Iteration 521 -- Loss: 0.014133
# Epoch 10, Iteration 522 -- Loss: 0.013505
# Epoch 10, Iteration 523 -- Loss: 0.015462
# Epoch 10, Iteration 524 -- Loss: 0.014843
# Epoch 10, Iteration 525 -- Loss: 0.014107
# Epoch 10, Iteration 526 -- Loss: 0.014236
# Epoch 10, Iteration 527 -- Loss: 0.014849
# Epoch 10, Iteration 528 -- Loss: 0.015913
# Epoch 10, Iteration 529 -- Loss: 0.016168
# Epoch 10, Iteration 530 -- Loss: 0.015198
# Epoch 10, Iteration 531 -- Loss: 0.015977
# Epoch 10, Iteration 532 -- Loss: 0.015020
# Epoch 10, Iteration 533 -- Loss: 0.016510
# Epoch 10, Iteration 534 -- Loss: 0.017375
# Epoch 10, Iteration 535 -- Loss: 0.017711
# Epoch 10, Iteration 536 -- Loss: 0.016260
# Epoch 10, Iteration 537 -- Loss: 0.014626
# Epoch 10, Iteration 538 -- Loss: 0.014300
# Epoch 10, Iteration 539 -- Loss: 0.013916
# Epoch 10, Iteration 540 -- Loss: 0.014075
# Epoch 10, Iteration 541 -- Loss: 0.014035
# Epoch 10, Iteration 542 -- Loss: 0.013939
# Epoch 10, Iteration 543 -- Loss: 0.015493
# Epoch 10, Iteration 544 -- Loss: 0.014454
# Epoch 10, Iteration 545 -- Loss: 0.014870
# Epoch 10, Iteration 546 -- Loss: 0.015078
# Epoch 10, Iteration 547 -- Loss: 0.015742
# Epoch 10, Iteration 548 -- Loss: 0.016047
# Epoch 10, Iteration 549 -- Loss: 0.015383
# Epoch 10, Iteration 550 -- Loss: 0.015466
# Epoch 10, Iteration 551 -- Loss: 0.015733
# Epoch 10, Iteration 552 -- Loss: 0.014983
# Epoch 10, Iteration 553 -- Loss: 0.014195
# Epoch 10, Iteration 554 -- Loss: 0.013851
# Epoch 10, Iteration 555 -- Loss: 0.014003
# Epoch 10, Iteration 556 -- Loss: 0.014847
# Epoch 10, Iteration 557 -- Loss: 0.018808
# Epoch 10, Iteration 558 -- Loss: 0.019211
# Epoch 10, Iteration 559 -- Loss: 0.017239
# Epoch 10, Iteration 560 -- Loss: 0.016002
# Epoch 10, Iteration 561 -- Loss: 0.014257
# Epoch 10, Iteration 562 -- Loss: 0.015275
# Epoch 10, Iteration 563 -- Loss: 0.015154
# Epoch 10, Iteration 564 -- Loss: 0.015065
# Epoch 10, Iteration 565 -- Loss: 0.014708
# Epoch 10, Iteration 566 -- Loss: 0.015426
# Epoch 10, Iteration 567 -- Loss: 0.014860
# Epoch 10, Iteration 568 -- Loss: 0.014686
# Epoch 10, Iteration 569 -- Loss: 0.014695
# Epoch 10, Iteration 570 -- Loss: 0.015611
# Epoch 10, Iteration 571 -- Loss: 0.015067
# Epoch 10, Iteration 572 -- Loss: 0.015625
# Epoch 10, Iteration 573 -- Loss: 0.014329
# Epoch 10, Iteration 574 -- Loss: 0.015686
# Epoch 10, Iteration 575 -- Loss: 0.015473
# Epoch 10, Iteration 576 -- Loss: 0.015597
# Epoch 10, Iteration 577 -- Loss: 0.014059
# Epoch 10, Iteration 578 -- Loss: 0.013892
# Epoch 10, Iteration 579 -- Loss: 0.013336

# %%
fig = plt.figure()
plt.plot(losses)
plt.show()
fig.savefig("output/loss.png")

# %%
#!zip content/output/file.zip content/output
# Out:
# 	zip warning: name not matched: content/output
#
# zip error: Nothing to do! (content/output/file.zip)
